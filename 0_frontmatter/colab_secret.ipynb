# %% [markdown]
# <a href="https://colab.research.google.com/github/ychoi-kr/llm-api-prog/blob/main/0_frontmatter/colab_secret.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 구글 코랩 보안 비밀

# %% [markdown]
# ### 보안 비밀 추가

# %% [markdown]
# 코랩 왼쪽 열쇠 아이콘을 눌러 보안 비밀 화면에서 'test' 보안 비밀을 추가합니다.

# %% [markdown]
# ### 보안 비밀 가져오기

# %%
from google.colab import userdata
userdata.get('test')  # 'test' 보안 비밀을 읽기
# Out:
# '123456'

# %%
# %pip install openai
# Out:
# Collecting openai
#   Downloading openai-2.43.0-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\choij\miniconda3\envs\aicv311\lib\site-packages (from openai) (4.13.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\choij\miniconda3\envs\aicv311\lib\site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.10.0 (from openai)
#   Downloading jiter-0.15.0-cp311-cp311-win_amd64.whl.metadata (5.3 kB)
# Collecting pydantic<3,>=1.9.0 (from openai)
#   Downloading pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Collecting sniffio (from openai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>4 in c:\users\choij\miniconda3\envs\aicv311\lib\site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\choij\miniconda3\envs\aicv311\lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\choij\miniconda3\envs\aicv311\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in c:\users\choij\miniconda3\envs\aicv311\lib\site-packages (from httpx<1,>=0.23.0->openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\choij\miniconda3\envs\aicv311\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\choij\miniconda3\envs\aicv311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->openai)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.4 (from pydantic<3,>=1.9.0->openai)
#   Downloading pydantic_core-2.46.4-cp311-cp311-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->openai)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: colorama in c:\users\choij\miniconda3\envs\aicv311\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading openai-2.43.0-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 23.3 MB/s  0:00:00
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.15.0-cp311-cp311-win_amd64.whl (200 kB)
# Downloading pydantic-2.13.4-py3-none-any.whl (472 kB)
# Downloading pydantic_core-2.46.4-cp311-cp311-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 38.5 MB/s  0:00:00
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: typing-inspection, sniffio, pydantic-core, jiter, distro, annotated-types, pydantic, openai
#
#    -------------------- ------------------- 4/8 [distro]
#    ------------------------------ --------- 6/8 [pydantic]
#    ------------------------------ --------- 6/8 [pydantic]
#    ------------------------------ --------- 6/8 [pydantic]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ----------------------------------- ---- 7/8 [openai]
#    ---------------------------------------- 8/8 [openai]
#
# Successfully installed annotated-types-0.7.0 distro-1.9.0 jiter-0.15.0 openai-2.43.0 pydantic-2.13.4 pydantic-core-2.46.4 sniffio-1.3.1 typing-inspection-0.4.2
# Note: you may need to restart the kernel to use updated packages.
